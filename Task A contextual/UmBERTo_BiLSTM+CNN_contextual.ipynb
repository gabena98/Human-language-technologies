# %%
! pip install transformers
! pip install keras_tuner
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /usr/lib/python3.8/site-packages (4.1.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/lib/python3.8/site-packages (from transformers) (4.54.1)
# Requirement already satisfied: filelock in /usr/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in /usr/lib/python3.8/site-packages (from transformers) (20.9)
# Requirement already satisfied: sacremoses in /usr/lib/python3.8/site-packages (from transformers) (0.0.43)
# Requirement already satisfied: regex!=2019.12.17 in /usr/lib/python3.8/site-packages (from transformers) (2020.11.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/lib/python3.8/site-packages (from transformers) (0.9.4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.22.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/lib/python3/dist-packages (from packaging->transformers) (2.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: joblib in /usr/lib/python3.8/site-packages (from sacremoses->transformers) (1.0.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_tuner in /storagenfs/g.benanti/.local/lib/python3.8/site-packages (1.4.6)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from keras_tuner) (2.22.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.6.0)
# Requirement already satisfied: kt-legacy in /storagenfs/g.benanti/.local/lib/python3.8/site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: packaging in /usr/lib/python3.8/site-packages (from keras_tuner) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/lib/python3/dist-packages (from packaging->keras_tuner) (2.4.6)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
# !echo $CUDA_VISIBLE_DEVICES
# Out:
# 3

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Embedding, LSTM, Bidirectional, Dropout, MaxPooling1D, concatenate, BatchNormalization, Conv1D, Flatten
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras_tuner.tuners import GridSearch
from keras_tuner import HyperModel, Objective
from keras import regularizers
from decimal import Decimal
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print("GPUs available: ", gpus)
# Out:
# GPUs available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
if gpus:
    # Assuming you want to use the first GPU if available
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        print("Using GPU: ", gpus[0])
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# Using GPU:  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# Memory growth enabled

# %%
import keras
SEED = 42
tf.random.set_seed(SEED)

# %%
choice = 'umberto' #umberto
max_length = 500
if choice == 'alberto':
    training_data = pd.read_csv('../Evalita2023/alberto_preprocessig_training/merged_alberto_preprocessing_training.csv')
    test_data = pd.read_csv('../Evalita2023/alberto_preprocessing_test/merged_alberto_preprocessing_test.csv')
    #max_length = 290
    print('alberto chosen')
else:
    training_data = pd.read_csv('../Evalita2023/umberto_preprocessig_training/merged_umberto_preprocessing_training.csv')
    test_data = pd.read_csv('../Evalita2023/umberto_preprocessing_test/merged_umberto_preprocessing_test.csv')
    #max_length = 357
    print('umberto chosen')

print(max_length)
# Out:
# umberto chosen
# 357

# %%
training_data
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 0         217874450618134  [user] con tutte le denunce che si sta beccand...
# 1         360042217507605  [hashtag] prescrizione [/hashtag] i t re magi ...
# 2         817917484817935  il [hashtag] movimento cinque stelle [/hashtag...
# 3         145836038456701  che cosa cambia questa [hashtag] legge [/hasht...
# 4         740684329660693  in pochi giorni il [hashtag] ministro [/hashta...
# ...                   ...                                                ...
# 4856      715670659156960  [hashtag] covid [/hashtag] [hashtag] draghi [/...
# 4857      512309888296620  cina [number] [number] [number] mila euro a ne...
# 4858      887061502405620  [user] [user] [user] anch io leggo i commenti ...
# 4859      531900858879345  trasporto pubblico simeone nominato consiglier...
# 4860      129706985183701                       ma chi cazzo è letta ? [url]
#
#       label            dataset  retweet_count  favorite_count  \
# 0         1  training_politics            0.0             6.0
# 1         0  training_politics          154.0           448.0
# 2         1  training_politics          195.0           638.0
# 3         0  training_politics           45.0           143.0
# 4         0  training_politics            2.0             8.0
# ...     ...                ...            ...             ...
# 4856      0  training_politics            2.0             2.0
# 4857      0  training_politics            0.0             0.0
# 4858      1  training_politics            1.0             2.0
# 4859      0  training_politics            0.0             0.0
# 4860      0  training_politics            0.0             0.0
#
#       anonymized_user_id  statuses_count  followers_count  friends_count  \
# 0           8.868893e+14           554.0            748.0          753.0
# 1           2.570741e+14         35043.0          10838.0         4535.0
# 2           6.908473e+14        139750.0           7971.0         1866.0
# 3           5.308388e+14         11234.0          10815.0         1810.0
# 4           7.081260e+14           473.0           1171.0         1353.0
# ...                  ...             ...              ...            ...
# 4856        3.198085e+14          8531.0            136.0           55.0
# 4857        8.161793e+14         30137.0           3905.0         1085.0
# 4858        8.840904e+14          2104.0            139.0          817.0
# 4859        8.368163e+14         20623.0            399.0           14.0
# 4860        9.145434e+14         10320.0            975.0         1813.0
#
#                                  anonymized_description
# 0     avete presente quegli stereotipi sui siciliani...
# 1     prof di latino e deputata pd ama lo sport la r...
# 2     medico appassionato di cinema d autore musica ...
# 3     veneto ! assessore regionale sviluppo economic...
# 4     napoletano tifoso della fiorentina e rivoluzio...
# ...                                                 ...
# 4856  passione per l informazione la conoscenza ci p...
# 4857  la prima radio sino italiana canale [number] d...
# 4858  dr computers science nessuna politica per le f...
# 4859  la provinciaonline è un sito d informazione ch...
# 4860                                            nessuna
#
# [4861 rows x 11 columns]

# %%
test_data
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 0         424801448454884  questo anno [hashtag] babbo natale [/hashtag] ...
# 1         775194088981616  adesso che in mezzo alla strada grazie al verg...
# 2         386928936347190  circondatevi di persone che non sono diventate...
# 3         957546674360002  seriamente per capire se un ladro mi entra in ...
# 4         530526299555950  che poi è probabile che [hashtag] spataro [/ha...
# ...                   ...                                                ...
# 3698      195156040845120  come nasce un regime per il terzo reich il pro...
# 3699      137041976681572  [hashtag] il resto del carlino [/hashtag] la l...
# 3700      391599381944152  [user] esatto brava ti dico di piu i nazisti n...
# 3701      974317501584882  [user] togliere la parola non vaccinati e mett...
# 3702      470933865054049  berlino memoriale per gli ebrei assassinati d ...
#
#       label         dataset  retweet_count  favorite_count  \
# 0         1   test_politics            486            1827
# 1         1   test_politics            581            1996
# 2         0   test_politics             47             252
# 3         0   test_politics              7              30
# 4         0   test_politics              0               0
# ...     ...             ...            ...             ...
# 3698      0  test_religious              0               0
# 3699      0  test_religious              0               0
# 3700      0  test_religious              0               0
# 3701      0  test_religious              0               0
# 3702      0  test_religious              4              55
#
#       anonymized_user_id  statuses_count  followers_count  friends_count  \
# 0        587049380396341           25758           132172          13522
# 1        924711002016921           27794            39224           4682
# 2         62043137600220           18643            10758           8690
# 3        801758473146114          132391             5621           2490
# 4        334768891377767           31009              423            306
# ...                  ...             ...              ...            ...
# 3698     775266801550239           20255              450            820
# 3699     826968386244550           22604              373            305
# 3700     157816101917459           10922              373            491
# 3701     194540947910741             721               31            169
# 3702     115722113108250            5672             2544           2501
#
#                                  anonymized_description
# 0     rigore è quando arbitro fischia non vero bosko...
# 1     agisci in modo da trattare l umanità in te com...
# 2                                                 [url]
# 3                  suora dal [number] [user] bloccami !
# 4     icastico interista seguo la palla al cesto so ...
# ...                                                 ...
# 3698  venezuela libre ! expect nothing prepare for e...
# 3699  dopo aver dato un consiglio concludo sempre co...
# 3700  il covid e le guerre sono il braccio armato de...
# 3701  galileo copernico giordano bruno furono consid...
# 3702  se pensi di non farcela riordina l armadio ten...
#
# [3703 rows x 11 columns]

# %%
test_religious_data = test_data.loc[test_data['dataset'] == 'test_religious']
test_politics_data = test_data.loc[test_data['dataset'] == 'test_politics']

# %%
test_politics_data
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 0         424801448454884  questo anno [hashtag] babbo natale [/hashtag] ...
# 1         775194088981616  adesso che in mezzo alla strada grazie al verg...
# 2         386928936347190  circondatevi di persone che non sono diventate...
# 3         957546674360002  seriamente per capire se un ladro mi entra in ...
# 4         530526299555950  che poi è probabile che [hashtag] spataro [/ha...
# ...                   ...                                                ...
# 2718      740119007060498  [user] il problema non sono le dosi cazzaro [u...
# 2719       92974117033041  [user] reddito di cittadinanza fatto da un gov...
# 2721      791719192220932  [user] sono assuefatti non se ne rendono nemme...
# 2798       25360395404144  [hashtag] sondaggio polito co [/hashtag] [hash...
# 3226      834806744745258  viviamo in un mondo dove è necessario scrivere...
#
#       label        dataset  retweet_count  favorite_count  anonymized_user_id  \
# 0         1  test_politics            486            1827     587049380396341
# 1         1  test_politics            581            1996     924711002016921
# 2         0  test_politics             47             252      62043137600220
# 3         0  test_politics              7              30     801758473146114
# 4         0  test_politics              0               0     334768891377767
# ...     ...            ...            ...             ...                 ...
# 2718      1  test_politics              0               0     412574071640870
# 2719      1  test_politics              0               0     504744452374305
# 2721      1  test_politics              0               3     702503684856325
# 2798      0  test_politics              0               0     546741055894686
# 3226      0  test_politics            138             849     559964991856276
#
#       statuses_count  followers_count  friends_count  \
# 0              25758           132172          13522
# 1              27794            39224           4682
# 2              18643            10758           8690
# 3             132391             5621           2490
# 4              31009              423            306
# ...              ...              ...            ...
# 2718            4008              319            289
# 2719             493                4            138
# 2721           11035              716            699
# 2798             156              117            394
# 3226           29210            19832           5381
#
#                                  anonymized_description
# 0     rigore è quando arbitro fischia non vero bosko...
# 1     agisci in modo da trattare l umanità in te com...
# 2                                                 [url]
# 3                  suora dal [number] [user] bloccami !
# 4     icastico interista seguo la palla al cesto so ...
# ...                                                 ...
# 2718  nel tempo del inganno universale dire la verit...
# 2719                   pensatore / filosofo meridionale
# 2721  bloccato da salvini antifa nel dna rocker per ...
# 2798  consulenza strategica integrata comunicazione ...
# 3226                                        irriverendo
#
# [1227 rows x 11 columns]

# %%
# Load model directly
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Musixmatch/umberto-commoncrawl-cased-v1")  #m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0 #Musixmatch/umberto-commoncrawl-cased-v1

def tokenize_function(sentence1, sentence2):
    tokens = tokenizer.encode_plus(sentence1, sentence2, max_length=max_length,
                                   truncation=True, padding='max_length',
                                   add_special_tokens=True, return_attention_mask=True,
                                   return_token_type_ids=False, return_tensors='tf')
    return tokens['input_ids'], tokens['attention_mask']

# %%
from sklearn.model_selection import train_test_split

labels = training_data['label']

X_train, X_val, y_train, y_val = train_test_split(training_data, labels, test_size=0.20, random_state=SEED, stratify=labels)

# %%
X_train.head()
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 2419      820323163384842  non prendetevela egregi gestori suddetti ma mi...
# 3279      498172779077527  [user] [user] [user] [user] mi dissocio a part...
# 3497      959416139898966  [user] questo è da prenderlo a calci nel culo ...
# 2190      367618236249208  dopo [number] di [hashtag] cassa integrazione ...
# 2838      148083376257936  [user] [user] che poi la carità di cui parla i...
#
#       label            dataset  retweet_count  favorite_count  \
# 2419      0  training_politics            0.0             0.0
# 3279      1  training_politics            0.0             0.0
# 3497      1  training_politics            0.0             3.0
# 2190      1  training_politics            0.0             0.0
# 2838      0  training_politics            0.0             0.0
#
#       anonymized_user_id  statuses_count  followers_count  friends_count  \
# 2419        9.366533e+14          4804.0            357.0          677.0
# 3279        2.302434e+14         11427.0            128.0          523.0
# 3497        6.167306e+13          7905.0            102.0          836.0
# 2190        6.027086e+14           297.0              3.0            9.0
# 2838        2.560303e+14        122627.0           2271.0         4994.0
#
#                                  anonymized_description
# 2419  scrivo libri faccio radio mi occupo di promozi...
# 3279  [hashtag] elezioni subito [/hashtag] in pensio...
# 3497  vado a comprare le sigarette ma se non fumi ? ...
# 2190                molto più che che un cuore di panna
# 2838                           salvo complicanze sempre

# %%
y_train.head()
# Out:
# 2419    0
# 3279    1
# 3497    1
# 2190    1
# 2838    0
# Name: label, dtype: int64

# %% [markdown]
# ### Normalize dataset

# %%
# Initialize the scaler
scaler = StandardScaler()
columns_to_normalize = ['retweet_count', 'favorite_count', 'statuses_count', 'followers_count', 'friends_count']

# Fit the scaler on the training data and transform it
X_train[columns_to_normalize] = scaler.fit_transform(X_train[columns_to_normalize])

# Transform the validation and test data with the same scaler
X_val[columns_to_normalize] = scaler.transform(X_val[columns_to_normalize])
test_religious_data[columns_to_normalize] = scaler.transform(test_religious_data[columns_to_normalize])
test_politics_data[columns_to_normalize] = scaler.transform(test_politics_data[columns_to_normalize])

X_train.head()
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 2419      820323163384842  non prendetevela egregi gestori suddetti ma mi...
# 3279      498172779077527  [user] [user] [user] [user] mi dissocio a part...
# 3497      959416139898966  [user] questo è da prenderlo a calci nel culo ...
# 2190      367618236249208  dopo [number] di [hashtag] cassa integrazione ...
# 2838      148083376257936  [user] [user] che poi la carità di cui parla i...
#
#       label            dataset  retweet_count  favorite_count  \
# 2419      0  training_politics      -0.248056       -0.212369
# 3279      1  training_politics      -0.248056       -0.212369
# 3497      1  training_politics      -0.248056       -0.203155
# 2190      1  training_politics      -0.248056       -0.212369
# 2838      0  training_politics      -0.248056       -0.212369
#
#       anonymized_user_id  statuses_count  followers_count  friends_count  \
# 2419        9.366533e+14       -0.209420        -0.162088      -0.371403
# 3279        2.302434e+14       -0.193195        -0.164952      -0.417355
# 3497        6.167306e+13       -0.201823        -0.165277      -0.323960
# 2190        6.027086e+14       -0.220461        -0.166515      -0.570726
# 2838        2.560303e+14        0.079220        -0.138151       0.916735
#
#                                  anonymized_description
# 2419  scrivo libri faccio radio mi occupo di promozi...
# 3279  [hashtag] elezioni subito [/hashtag] in pensio...
# 3497  vado a comprare le sigarette ma se non fumi ? ...
# 2190                molto più che che un cuore di panna
# 2838                           salvo complicanze sempre

# %%
X_val.head()
# Out:
#       anonymized_tweet_id                                    anonymized_text  \
# 1390       17202875150669  è [hashtag] bullismo [/hashtag] anche la [hash...
# 4040      148908204400470  situazione attuale italia uno sta picconando i...
# 3808      328868193922911  amo l italia ma i suoi [hashtag] politici [/ha...
# 774       862308711639804  la vera differenza tra coalizione [hashtag] mo...
# 1062      448098502906783  fuori dalla maggioranza con un popolo di [hash...
#
#       label            dataset  retweet_count  favorite_count  \
# 1390      0  training_politics      -0.248056       -0.209298
# 4040      1  training_politics      -0.141249       -0.150938
# 3808      0  training_politics      -0.114547        0.331298
# 774       0  training_politics      -0.248056       -0.212369
# 1062      0  training_politics       0.392787        0.233008
#
#       anonymized_user_id  statuses_count  followers_count  friends_count  \
# 1390        4.085561e+14       -0.218918        -0.165915      -0.502992
# 4040        6.844551e+14       -0.188751        -0.143291      -0.077492
# 3808        5.740365e+13       -0.216343        -0.110600       0.851985
# 774         2.599462e+13       -0.203808        -0.164589      -0.516420
# 1062        9.381988e+14       -0.200885        -0.074358       1.577364
#
#                                  anonymized_description
# 1390  mama always said life was like a box of chocol...
# 4040  comunista antipatica nata nel mondo la sola pa...
# 3808  su twitter perché non mi arrendo a un italia c...
# 774   nosce te ipsum veritas vos liberat il mondo ec...
# 1062  autore di satira mi trovate su [user] [user] [...

# %% [markdown]
# ### creating dataset

# %%
# initialize two arrays for input tensors
Xids = np.zeros((len(X_train['anonymized_text']), max_length))
Xmask = np.zeros((len(X_train['anonymized_text']), max_length))
Xmeta = X_train[['retweet_count', 'favorite_count', 'statuses_count', 'followers_count', 'friends_count']]

for i, (sentence1, sentence2) in enumerate(zip(X_train['anonymized_text'],X_train['anonymized_description'])):
    Xids[i, :], Xmask[i, :] = tokenize_function(sentence1, sentence2)

# %%
labels = y_train
BATCH_SIZE = 128  # we will use batches of 128

# load arrays into tensorflow dataset
dataset = tf.data.Dataset.from_tensor_slices((Xids, Xmask, Xmeta, labels))

# create a mapping function that we use to restructure our dataset
def map_func(input_ids, masks, metadata, labels):
    return {'input_ids': input_ids, 'attention_mask': masks, 'meta_input': metadata}, labels

# using map method to apply map_func to dataset
dataset = dataset.map(map_func)

# batch data
dataset = dataset.batch(BATCH_SIZE)
train=dataset
del dataset

# %%
XidsVal = np.zeros((len(X_val['anonymized_text']), max_length))
XmaskVal = np.zeros((len(X_val['anonymized_text']), max_length))
XmetaVal = X_val[['retweet_count', 'favorite_count', 'statuses_count', 'followers_count', 'friends_count']]

for i, (sentence1, sentence2) in enumerate(zip(X_val['anonymized_text'], X_val['anonymized_description'])):
    XidsVal[i, :], XmaskVal[i, :] = tokenize_function(sentence1, sentence2)
labels_val = y_val

dataset = tf.data.Dataset.from_tensor_slices((XidsVal, XmaskVal, XmetaVal, labels_val))
dataset = dataset.map(map_func)
dataset = dataset.batch(BATCH_SIZE)
validation = dataset
del dataset

# %%
XidsTestPolitics = np.zeros((len(test_politics_data['anonymized_text']), max_length))
XmaskTestPolitics = np.zeros((len(test_politics_data['anonymized_text']), max_length))
XmetaTestPolitics = test_politics_data[['retweet_count', 'favorite_count', 'statuses_count', 'followers_count', 'friends_count']]

for i, (sentence1, sentence2) in enumerate(zip(test_politics_data['anonymized_text'],test_politics_data['anonymized_description'])):
    XidsTestPolitics[i, :], XmaskTestPolitics[i, :] = tokenize_function(sentence1, sentence2)

labelsTPolitics = test_politics_data['label']

dataset = tf.data.Dataset.from_tensor_slices((XidsTestPolitics, XmaskTestPolitics, XmetaTestPolitics,labelsTPolitics))
dataset = dataset.map(map_func)
dataset = dataset.batch(BATCH_SIZE)
test_politics = dataset

del dataset  # delete dataset to free up disk-space

# %%
XidsTestReligious = np.zeros((len(test_religious_data['anonymized_text']), max_length))
XmaskTestReligious = np.zeros((len(test_religious_data['anonymized_text']), max_length))
XmetaTestReligious = test_religious_data[['retweet_count', 'favorite_count', 'statuses_count', 'followers_count', 'friends_count']]

for i, (sentence1, sentence2) in enumerate(zip(test_religious_data['anonymized_text'],test_religious_data['anonymized_description'])):
    XidsTestReligious[i, :], XmaskTestReligious[i, :] = tokenize_function(sentence1, sentence2)

labelsTReligious = test_religious_data['label']

dataset = tf.data.Dataset.from_tensor_slices((XidsTestReligious, XmaskTestReligious, XmetaTestReligious ,labelsTReligious))
dataset = dataset.map(map_func)
dataset = dataset.batch(BATCH_SIZE)
test_religious = dataset

del dataset  # delete dataset to free up disk-space

# %% [markdown]
# ### Model training/testing

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Precision, Recall
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()
    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + tf.keras.backend.epsilon()))
    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
from transformers import TFAutoModel

class MyHyperModel(HyperModel):
    def build(self, hp):
        model = TFAutoModel.from_pretrained("Musixmatch/umberto-commoncrawl-cased-v1", from_pt=True) #m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0 #Musixmatch/umberto-commoncrawl-cased-v1

        input_ids = Input(shape=(max_length,), name='input_ids', dtype='int32')
        mask = Input(shape=(max_length,), name='attention_mask', dtype='int32')
        meta_input = Input(shape=(Xmeta.shape[1],), name='meta_input', dtype='float32')

        # we consume the last_hidden_state tensor from bert (discarding pooled_outputs)
        embeddings = model(input_ids, attention_mask=mask)[0]

        X = Bidirectional(LSTM(units=hp.Choice('LSTM_units', values=[64, 128]), return_sequences= True))(embeddings) 
        X = Conv1D(filters=hp.Choice('filters', values=[32, 128]), kernel_size=hp.Choice('kernel_size', values=[3,9]), activation="relu")(X)
        X = MaxPooling1D(2)(X)
        X = Dropout(rate=hp.Choice('rate_dropout', values=[0.6, 0.7]))(X)
        X = Flatten()(X)
        X = concatenate([X, meta_input])
        #X = BatchNormalization()(X)
        X = Dense(units=hp.Choice('dense_units', values=[16,32,64]), kernel_regularizer=regularizers.L2(hp.Choice('reg_value', values=[0.0,0.001])), activation="relu")(X)
        y = Dense(1, activation='sigmoid', name='outputs')(X)

        # define input and output layers of our model
        best_model = Model(inputs=[input_ids, mask, meta_input], outputs=y)

        # freeze the BERT layer - otherwise we will be training 100M+ parameters...
        best_model.layers[2].trainable = False

        best_model.compile(optimizer=Adam(learning_rate = hp.Choice('learning_rate', values=[0.01, 1e-3]), clipnorm = 3), loss="binary_crossentropy", metrics=[F1Score()])
        return best_model

# %%
tuner = GridSearch(
    hypermodel = MyHyperModel(),
    objective = Objective('val_loss', 'min'),
    max_trials = 15,
    seed = SEED,
    executions_per_trial = 1,
    overwrite = False,
    project_name="UmBerto_BiLSTM+CNN_contextual")
# Out:
# Reloading Tuner from ./UmBerto_BiLSTM+CNN_contextual/tuner0.json

# %%
tuner.search_space_summary(extended=True)
# Out:
# Search space summary
# Default search space size: 7
# LSTM_units (Choice)
# {'default': 64, 'conditions': [], 'values': [64, 128], 'ordered': True}
# filters (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 128], 'ordered': True}
# kernel_size (Choice)
# {'default': 3, 'conditions': [], 'values': [3, 9], 'ordered': True}
# rate_dropout (Choice)
# {'default': 0.6, 'conditions': [], 'values': [0.6, 0.7], 'ordered': True}
# dense_units (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64], 'ordered': True}
# reg_value (Choice)
# {'default': 0.0, 'conditions': [], 'values': [0.0, 0.001], 'ordered': True}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001], 'ordered': True}

# %%
es = EarlyStopping(monitor='val_loss', patience=3,restore_best_weights=True, verbose=1)
tuner.search(train, epochs=15, validation_data=validation, callbacks=[es])

# %%
# Random Search 10 best results
tuner.results_summary()
# Out:
# Results summary
# Results in ./UmBerto_BiLSTM+CNN_contextual
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 12 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.7
# dense_units: 16
# reg_value: 0.0
# learning_rate: 0.01
# Score: 0.3056238889694214
#
# Trial 13 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.7
# dense_units: 16
# reg_value: 0.0
# learning_rate: 0.001
# Score: 0.30570316314697266
#
# Trial 01 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 16
# reg_value: 0.0
# learning_rate: 0.001
# Score: 0.30752143263816833
#
# Trial 09 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 64
# reg_value: 0.0
# learning_rate: 0.001
# Score: 0.31320151686668396
#
# Trial 05 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 32
# reg_value: 0.0
# learning_rate: 0.001
# Score: 0.3153253197669983
#
# Trial 03 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 16
# reg_value: 0.001
# learning_rate: 0.001
# Score: 0.31600311398506165
#
# Trial 07 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 32
# reg_value: 0.001
# learning_rate: 0.001
# Score: 0.3266439437866211
#
# Trial 08 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 64
# reg_value: 0.0
# learning_rate: 0.01
# Score: 0.3288530707359314
#
# Trial 11 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 64
# reg_value: 0.001
# learning_rate: 0.001
# Score: 0.34775403141975403
#
# Trial 10 summary
# Hyperparameters:
# LSTM_units: 64
# filters: 32
# kernel_size: 3
# rate_dropout: 0.6
# dense_units: 64
# reg_value: 0.001
# learning_rate: 0.01
# Score: 0.4751456677913666

# %%
# Focus on Best Trial
tuner.oracle.get_best_trials()[0].get_state()
# Out:
# {'trial_id': '12',
#  'hyperparameters': {'space': [{'class_name': 'Choice',
#     'config': {'name': 'LSTM_units',
#      'default': 64,
#      'conditions': [],
#      'values': [64, 128],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'filters',
#      'default': 32,
#      'conditions': [],
#      'values': [32, 128],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'kernel_size',
#      'default': 3,
#      'conditions': [],
#      'values': [3, 9],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'rate_dropout',
#      'default': 0.6,
#      'conditions': [],
#      'values': [0.6, 0.7],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'dense_units',
#      'default': 16,
#      'conditions': [],
#      'values': [16, 32, 64],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'reg_value',
#      'default': 0.0,
#      'conditions': [],
#      'values': [0.0, 0.001],
#      'ordered': True}},
#    {'class_name': 'Choice',
#     'config': {'name': 'learning_rate',
#      'default': 0.01,
#      'conditions': [],
#      'values': [0.01, 0.001],
#      'ordered': True}}],
#   'values': {'LSTM_units': 64,
#    'filters': 32,
#    'kernel_size': 3,
#    'rate_dropout': 0.7,
#    'dense_units': 16,
#    'reg_value': 0.0,
#    'learning_rate': 0.01}},
#  'metrics': {'metrics': {'loss': {'direction': 'min',
#     'observations': [{'value': [0.26368674635887146], 'step': 10}]},
#    'f1_score': {'direction': 'min',
#     'observations': [{'value': [0.8547444343566895], 'step': 10}]},
#    'val_loss': {'direction': 'min',
#     'observations': [{'value': [0.3056238889694214], 'step': 10}]},
#    'val_f1_score': {'direction': 'min',
#     'observations': [{'value': [0.8181817531585693], 'step': 10}]}}},
#  'score': 0.3056238889694214,
#  'best_step': 10,
#  'status': 'COMPLETED',
#  'message': None}

# %%
# Focus on Best Trial
best_hps = tuner.get_best_hyperparameters()[0]
best_hps.values
# Out:
# {'LSTM_units': 64,
#  'filters': 32,
#  'kernel_size': 3,
#  'rate_dropout': 0.7,
#  'dense_units': 16,
#  'reg_value': 0.0,
#  'learning_rate': 0.01}

# %%
# Best Model
best_model = tuner.hypermodel.build(best_hps)
best_model.summary()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFCamembertModel: ['lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing TFCamembertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFCamembertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFCamembertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCamembertModel for predictions without further training.
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 357)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 357)]        0
# __________________________________________________________________________________________________
# tf_camembert_model_2 (TFCamembe TFBaseModelOutputWit 110621952   input_ids[0][0]
#                                                                  attention_mask[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 357, 128)     426496      tf_camembert_model_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 355, 32)      12320       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 177, 32)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 177, 32)      0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 5664)         0           dropout_113[0][0]
# __________________________________________________________________________________________________
# meta_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5669)         0           flatten_2[0][0]
#                                                                  meta_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           90720       concatenate_2[0][0]
# __________________________________________________________________________________________________
# outputs (Dense)                 (None, 1)            17          dense_2[0][0]
# ==================================================================================================
# Total params: 111,151,505
# Trainable params: 529,553
# Non-trainable params: 110,621,952
# __________________________________________________________________________________________________

# %%
# Training of best model
es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
history = best_model.fit(train, batch_size=BATCH_SIZE, epochs=60, callbacks=es, validation_data=validation)
# Out:
# Epoch 1/60
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 31/31 [==============================] - ETA: 0s - loss: 0.9192 - f1_score: 0.1181
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 31/31 [==============================] - 106s 3s/step - loss: 0.9192 - f1_score: 0.1181 - val_loss: 0.6507 - val_f1_score: 0.0000e+00
# Epoch 2/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.6529 - f1_score: 0.0000e+00 - val_loss: 0.6211 - val_f1_score: 0.0000e+00
# Epoch 3/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.5768 - f1_score: 0.0856 - val_loss: 0.5026 - val_f1_score: 0.5050
# Epoch 4/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.4849 - f1_score: 0.6249 - val_loss: 0.4421 - val_f1_score: 0.7726
# Epoch 5/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.4042 - f1_score: 0.7521 - val_loss: 0.3380 - val_f1_score: 0.8179
# Epoch 6/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.3337 - f1_score: 0.8105 - val_loss: 0.3138 - val_f1_score: 0.8100
# Epoch 7/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.3247 - f1_score: 0.8225 - val_loss: 0.3029 - val_f1_score: 0.8286
# Epoch 8/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2776 - f1_score: 0.8456 - val_loss: 0.3022 - val_f1_score: 0.8397
# Epoch 9/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2514 - f1_score: 0.8625 - val_loss: 0.3091 - val_f1_score: 0.8375
# Epoch 10/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2500 - f1_score: 0.8633 - val_loss: 0.3025 - val_f1_score: 0.8476
# Epoch 11/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2365 - f1_score: 0.8700 - val_loss: 0.3183 - val_f1_score: 0.8427
# Epoch 12/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2452 - f1_score: 0.8753 - val_loss: 0.3436 - val_f1_score: 0.8378
# Epoch 13/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2264 - f1_score: 0.8815 - val_loss: 0.2898 - val_f1_score: 0.8365
# Epoch 14/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.2152 - f1_score: 0.8849 - val_loss: 0.3082 - val_f1_score: 0.8430
# Epoch 15/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1994 - f1_score: 0.9002 - val_loss: 0.3298 - val_f1_score: 0.8476
# Epoch 16/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1868 - f1_score: 0.8957 - val_loss: 0.3812 - val_f1_score: 0.8153
# Epoch 17/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1788 - f1_score: 0.9034 - val_loss: 0.3934 - val_f1_score: 0.8213
# Epoch 18/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1722 - f1_score: 0.9105 - val_loss: 0.3549 - val_f1_score: 0.8300
# Epoch 19/60
# 31/31 [==============================] - 75s 2s/step - loss: 0.1715 - f1_score: 0.9128 - val_loss: 0.3720 - val_f1_score: 0.8427
# Epoch 20/60
# 31/31 [==============================] - 75s 2s/step - loss: 0.1623 - f1_score: 0.9133 - val_loss: 0.5006 - val_f1_score: 0.8283
# Epoch 21/60
# 31/31 [==============================] - 75s 2s/step - loss: 0.1552 - f1_score: 0.9200 - val_loss: 0.4465 - val_f1_score: 0.8364
# Epoch 22/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1702 - f1_score: 0.9075 - val_loss: 0.4431 - val_f1_score: 0.8373
# Epoch 23/60
# 31/31 [==============================] - 74s 2s/step - loss: 0.1440 - f1_score: 0.9230 - val_loss: 0.4783 - val_f1_score: 0.8341
# Restoring model weights from the end of the best epoch.
# Epoch 00023: early stopping

# %%
#F1-score plot
plt.plot(history.history["f1_score"][:14], label='f1 score')
plt.plot(history.history["val_f1_score"][:14], label='val f1 score')
plt.xlabel('Epochs')
plt.ylabel('F1')
plt.ylim()
#plt.xticks(np.arange(len(history.history["val_f1_score"])), np.arange(1, len(history.history["val_f1_score"])+1))
plt.legend(loc = 'lower right')

# %%
#Loss plot
plt.plot(history.history["loss"][:14], label='loss')
plt.plot(history.history["val_loss"][:14], label='val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim()
#plt.xticks(np.arange(len(history.history["loss"])), np.arange(1, len(history.history["loss"])+1))
#plt.xticks(np.arange(len(history.history["val_loss"])), np.arange(1, len(history.history["val_loss"])+1))
plt.legend(loc = 'upper right')

# %%
pred_politics = best_model.predict(test_politics) > 0.5
# Out:
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.

# %%
# Getting the Classification Report
print(classification_report(list(labelsTPolitics), pred_politics, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8691    0.9497    0.9076       636
#            1     0.9398    0.8460    0.8905       591
#
#     accuracy                         0.8998      1227
#    macro avg     0.9045    0.8979    0.8990      1227
# weighted avg     0.9032    0.8998    0.8993      1227

# %%
pred_religious = best_model.predict(test_religious) > 0.5

# %%
# Getting the Classification Report
print(classification_report(list(labelsTReligious), pred_religious, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8623    0.9455    0.9020      2112
#            1     0.2812    0.1236    0.1718       364
#
#     accuracy                         0.8247      2476
#    macro avg     0.5718    0.5346    0.5369      2476
# weighted avg     0.7768    0.8247    0.7946      2476
