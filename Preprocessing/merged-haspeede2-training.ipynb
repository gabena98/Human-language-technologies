# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
haspeede2_df = pd.read_table('/content/drive/Shareddrives/HLT/dataset/development/haspeede2-task-AB/haspeede2_dev_taskAB.tsv')

# %%
haspeede2_df.head()
# Out:
#      id                                              text   hs  stereotype
# 0  2066  È terrorismo anche questo, per mettere in uno ...   0           0
# 1  2045  @user @user infatti finché ci hanno guadagnato...   0           0
# 2    61  Corriere: Tangenti, Mafia Capitale dimenticata...   0           0
# 3  1259  @user ad uno ad uno, perché quando i migranti ...   0           0
# 4   949  Il divertimento del giorno? Trovare i patrioti...   0           0

# %%
training_df = pd.read_csv('/content/drive/Shareddrives/HLT/dataset/development/training_textual.csv')

# %%
training_df.head()
# Out:
#                                         anonymized_text  label
# 5595  #Covid. #Draghi non fare come #Conte. La #poli...      0
# 5596  Cina, «128mila euro a neonato»: la proposta pe...      0
# 5597  @401560935985106 @507718538254873 @28429789767...      1
# 5598  Trasporto pubblico, Simeone nominato consiglie...      0
# 5599                      ma chi cazzo è letta? \n[URL]      0

# %%
training_df['dataset'].unique()
# Out:
# array(['training_politics'], dtype=object)

# %%
training_df.drop(columns=['anonymized_tweet_id', 'dataset'], inplace=True)

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   anonymized_text  5600 non-null   object
#  1   label            5600 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 87.6+ KB

# %%
haspeede2_df_renamed = haspeede2_df.rename(columns={'text ': 'anonymized_text', 'hs':'label'})

# %%
haspeede2_df_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6837 entries, 0 to 6836
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               6837 non-null   int64
#  1   anonymized_text  6837 non-null   object
#  2   label            6837 non-null   int64
#  3   stereotype       6837 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 213.8+ KB

# %%
haspeede2_df_renamed['label'].value_counts(True)
# Out:
# 0    0.595437
# 1    0.404563
# Name: label, dtype: float64

# %%
haspeede2_df_renamed.drop(columns=['id', 'stereotype'], inplace=True)

# %%
haspeede2_df_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6837 entries, 0 to 6836
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   anonymized_text  6837 non-null   object
#  1   label            6837 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 107.0+ KB

# %%
new_training_taskb = pd.concat([training_df, haspeede2_df_renamed], ignore_index = True)

# %%
new_training_taskb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12437 entries, 0 to 12436
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   anonymized_text  12437 non-null  object
#  1   label            12437 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 194.5+ KB

# %%
new_training_taskb.tail(6837)
# Out:
#                                          anonymized_text  label
# 5600   È terrorismo anche questo, per mettere in uno ...      0
# 5601   @user @user infatti finché ci hanno guadagnato...      0
# 5602   Corriere: Tangenti, Mafia Capitale dimenticata...      0
# 5603   @user ad uno ad uno, perché quando i migranti ...      0
# 5604   Il divertimento del giorno? Trovare i patrioti...      0
# ...                                                  ...    ...
# 12432  Gli stati nazionali devono essere pronti a rin...      0
# 12433  Il ministro dell'interno della Germania #Horst...      0
# 12434  #Salvini: In Italia troppi si sono montati la ...      0
# 12435  @user @user Chi giubila in buona fede non ha c...      0
# 12436  I giovani cristiani in #Etiopia sono indotti d...      0
#
# [6837 rows x 2 columns]

# %%
new_training_taskb['label'].value_counts(True)
# Out:
# 0    0.60521
# 1    0.39479
# Name: label, dtype: float64

# %%
new_training_taskb.to_csv('/content/drive/Shareddrives/HLT/dataset/development/haspeede2-task-AB/merged_training_textual-haspeede2.csv',index=False)
